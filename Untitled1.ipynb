# %% [markdown]
# # Marvel and DC Charcter stats

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('charcters_stats.csv')

# %%
df.head(10)
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0       3-D Man      good            50        31     43          32     25
# 1        A-Bomb      good            38       100     17          80     17
# 2    Abe Sapien      good            88        14     35          42     35
# 3      Abin Sur      good            50        90     53          64     84
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 6   Adam Monroe      good            63        10     12         100     71
# 7  Adam Strange      good             1         1      1           1      0
# 8     Agent  13      good             1         1      1           1      0
# 9     Agent Bob      good            10         8     13           5      5
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436
# 5      56    526
# 6      64    320
# 7       1      5
# 8       1      5
# 9      20     61

# %%
df.shape
# Out:
# (611, 9)

# %%
df.describe()
# Out:
#        Intelligence    Strength       Speed  Durability       Power  \
# count    611.000000  611.000000  611.000000  611.000000  611.000000
# mean      44.502455   29.083470   27.306056   41.839607   40.312602
# std       32.924722   32.610939   25.760173   36.543849   34.539910
# min        1.000000    1.000000    1.000000    1.000000    0.000000
# 25%        1.000000    1.000000    1.000000    1.000000    0.000000
# 50%       50.000000   10.000000   23.000000   32.000000   37.000000
# 75%       75.000000   53.000000   42.000000   80.000000   67.000000
# max      113.000000  100.000000  100.000000  120.000000  100.000000
#
#            Combat       Total
# count  611.000000  611.000000
# mean    43.206219  226.250409
# std     33.270329  167.324034
# min      1.000000    5.000000
# 25%      1.000000    5.000000
# 50%     50.000000  255.000000
# 75%     70.000000  351.500000
# max    101.000000  581.000000

# %%
df.boxplot()

# %%
df.hist(figsize = (15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF260D508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2EAA3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2ECEA08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2B27448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2B5EE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2B9A748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2BD23C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2C0A508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000028BF2C18108>]],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
# Name            611 non-null object
# Alignment       608 non-null object
# Intelligence    611 non-null int64
# Strength        611 non-null int64
# Speed           611 non-null int64
# Durability      611 non-null int64
# Power           611 non-null int64
# Combat          611 non-null int64
# Total           611 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 43.1+ KB

# %% [markdown]
# ### Data Clean

# %%
df.isnull()
# Out:
#       Name  Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0    False      False         False     False  False       False  False
# 1    False      False         False     False  False       False  False
# 2    False      False         False     False  False       False  False
# 3    False      False         False     False  False       False  False
# 4    False      False         False     False  False       False  False
# ..     ...        ...           ...       ...    ...         ...    ...
# 606  False      False         False     False  False       False  False
# 607  False      False         False     False  False       False  False
# 608  False      False         False     False  False       False  False
# 609  False      False         False     False  False       False  False
# 610  False      False         False     False  False       False  False
#
#      Combat  Total
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# ..      ...    ...
# 606   False  False
# 607   False  False
# 608   False  False
# 609   False  False
# 610   False  False
#
# [611 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Name            0
# Alignment       3
# Intelligence    0
# Strength        0
# Speed           0
# Durability      0
# Power           0
# Combat          0
# Total           0
# dtype: int64

# %%
df[df.Total > 600]
# Out:
# Empty DataFrame
# Columns: [Name, Alignment, Intelligence, Strength, Speed, Durability, Power, Combat, Total]
# Index: []

# %%
threshold = len(df) *0.1

# %%
threshold
# Out:
# 61.1

# %%
df.dropna(thresh = threshold , axis = 1  ,inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
# Name            611 non-null object
# Alignment       608 non-null object
# Intelligence    611 non-null int64
# Strength        611 non-null int64
# Speed           611 non-null int64
# Durability      611 non-null int64
# Power           611 non-null int64
# Combat          611 non-null int64
# Total           611 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 43.1+ KB

# %%
df["Alignment"].mode()
# Out:
# 0    good
# dtype: object

# %%
df['Alignment'].fillna(str(df['Alignment'].mode()),  inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
# Name            611 non-null object
# Alignment       611 non-null object
# Intelligence    611 non-null int64
# Strength        611 non-null int64
# Speed           611 non-null int64
# Durability      611 non-null int64
# Power           611 non-null int64
# Combat          611 non-null int64
# Total           611 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 43.1+ KB

# %%
df.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
x = df["Name"]
y = df["Intelligence"]
plt.plot(x,y)

# %%
sns.boxplot(x="Name",y="Intelligence",data=df)
